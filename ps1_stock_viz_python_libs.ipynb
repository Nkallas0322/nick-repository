# 2239  11072800
# 2240  22418300
# 2241  10027700
# 2242   9273300
# 2243   8109000
# 2244   9178200
# 2245   8259500
# 2246   6136500
# 2247   7028300
# 2248   5564200
# 2249   4776500
# 2250   5274300
# 2251   3898200
# 2252   4663900
# 2253   4848100
# 2254   9562600
# 2255   8159600
# 2256   5098500
# 2257   5309600
# 2258   4125200
# 2259   7794300
# 2260   6559000
# 2261   8538600
# 2262   5051900
# 2263   5416200
#
# [2264 rows x 7 columns]

# %%
tsla.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
tsla.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
tsla.values
# Out:
# array([['2010-08-30', 19.700001, 20.190001000000002, ...,
#         19.870001000000002, 19.870001000000002, 732800],
#        ['2010-08-31', 19.66, 19.790001, ..., 19.48, 19.48, 201100],
#        ['2010-09-01', 19.620001000000002, 20.690001000000002, ...,
#         20.450001, 20.450001, 494900],
#        ...,
#        ['2019-08-23', 219.97000099999997, 221.169998, ..., 211.399994,
#         211.399994, 8538600],
#        ['2019-08-26', 213.600006, 215.020004, ..., 215.0, 215.0, 5051900],
#        ['2019-08-27', 215.74000499999997, 218.80000299999998, ...,
#         214.080002, 214.080002, 5416200]], dtype=object)

# %%
tsla.size
# Out:
# 15848

# %%
tsla.empty
# Out:
# False

# %% [markdown]
# #### 4. Use pandas DataFrame methods to show information and manipulate the dataset.

# %% [markdown]
# Show descriptive statistics:

# %%
tsla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2264.000000  2264.000000  2264.000000  2264.000000  2264.000000
# mean    181.712778   184.853003   178.378352   181.708993   181.708993
# std     112.542163   114.274684   110.667577   112.540258   112.540258
# min      19.620001    19.790001    19.330000    19.480000    19.480000
# 25%      34.490000    34.995000    33.799999    34.430000    34.430000
# 50%     210.154999   214.000000   206.650002   209.970001   209.970001
# 75%     262.287498   265.667511   257.865005   262.099991   262.099991
# max     386.690002   389.609985   379.350006   385.000000   385.000000
#
#              Volume
# count  2.264000e+03
# mean   5.365184e+06
# std    4.671656e+06
# min    1.185000e+05
# 25%    1.839950e+06
# 50%    4.463750e+06
# 75%    7.166375e+06
# max    3.716390e+07

# %% [markdown]
# Show first five rows:

# %%
tsla.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2010-08-30  19.700001  20.190001  19.610001  19.870001  19.870001  732800
# 1  2010-08-31  19.660000  19.790001  19.330000  19.480000  19.480000  201100
# 2  2010-09-01  19.620001  20.690001  19.600000  20.450001  20.450001  494900
# 3  2010-09-02  20.370001  21.240000  20.309999  21.059999  21.059999  487100
# 4  2010-09-03  20.870001  21.299999  20.660000  21.049999  21.049999  434600

# %% [markdown]
# Show correlations among features:

# %%
tsla.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999554  0.999535  0.998986   0.998986  0.452064
# High       0.999554  1.000000  0.999464  0.999604   0.999604  0.460974
# Low        0.999535  0.999464  1.000000  0.999555   0.999555  0.442269
# Close      0.998986  0.999604  0.999555  1.000000   1.000000  0.451975
# Adj Close  0.998986  0.999604  0.999555  1.000000   1.000000  0.451975
# Volume     0.452064  0.460974  0.442269  0.451975   0.451975  1.000000

# %% [markdown]
# #### 5. Perform a correlation between two different datasets. We'll analyze Tesla's closing stock price and Ford's closing stock price.

# %% [markdown]
# Load Ford's stock data:

# %%
ford = pd.read_csv("f.csv")

# %% [markdown]
# Check to see it is loaded:

# %%
ford.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-08-30  11.58  11.68  11.35  11.35   8.103217  33651500
# 1  2010-08-31  11.27  11.46  11.13  11.29   8.060384  64984700
# 2  2010-09-01  11.53  11.89  11.46  11.61   8.288841  81988800
# 3  2010-09-02  11.68  11.83  11.57  11.71   8.360237  39943600
# 4  2010-09-03  11.88  12.14  11.84  12.07   8.617258  65243900

# %% [markdown]
# Check to see if the dimensions of each dataset are equal:

# %%
tsla.shape
ford.shape
# Out:
# (2264, 7)

# %% [markdown]
# Now perform the correlation:

# %%
tsla.corrwith(ford)
# Out:
# Open        -0.164613
# High        -0.172042
# Low         -0.155612
# Close       -0.164947
# Adj Close    0.257542
# Volume      -0.144686
# dtype: float64

# %% [markdown]
# #### 6. Now let's practice plotting the data.
#
# We will be using the 'Close' column of the Tesla dataset to analyze trends in the price of the stock since 2010.
#
# Within the plot, we will also compute moving averages to determine whether Tesla stock has experienced the "death cross", which is a technical indicator.
#
# * The death cross is a technical chart pattern indicating the potential for a major selloff.
# * The death cross appears on a chart when a stock’s short-term moving average crosses below its long-term moving average.
# * The death cross indicator has proven to be a reliable predictor of some of the most severe bear markets of the past century: 1929, 1938, 1974, and 2008
# * The death cross can be contrasted with a golden cross indicating a bull price movement.

# %% [markdown]
# First, let's isolate the closing price data:

# %%
tsla_close = tsla.loc[:,'Close']

# %% [markdown]
# Check the data:

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(tsla_close.index, tsla_close, label='TSLA')
ax.plot(tsla_close.index, tsla_close.rolling(window=50).mean(), label='50-day moving average')
ax.plot(tsla_close.index, tsla_close.rolling(window+200).mean(), label='200-day moving average')

#I'm going to set the x label to Date
ax.set_xlabel('Date')
ax.set_ylabel('Closing price ($)')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-dd17d015858c> in <module>
#       3 ax.plot(tsla_close.index, tsla_close, label='TSLA')
#       4 ax.plot(tsla_close.index, tsla_close.rolling(window=50).mean(), label='50-day moving average')
# ----> 5 ax.plot(tsla_close.index, tsla_close.rolling(window+200).mean(), label='200-day moving average')
#       6
#       7 #I'm going to set the x label to Date
#
# NameError: name 'window' is not defined

# %% [markdown]
# Plot just the closing data using the matplotlib library which was imported in the first part:

# %% [markdown]
# #### 7. Your assignment:
# * Import one Apple's stock price data. Make sure to download the CSV file into the correct directory.
# * Plot the same chart as we did for Tesla using Apple's data.
# * Upload your jupyer notebook to GitHub and email me the link to your GitHub page.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
aapl = pd.read_csv("AAPL.csv")

# %%
aapl
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-08-30   34.394287   35.107143   34.382858   34.642857   30.233280
# 1     2010-08-31   34.549999   34.937141   34.335712   34.728573   30.308084
# 2     2010-09-01   35.352856   35.922855   35.182858   35.761429   31.209463
# 3     2010-09-02   35.894287   36.024284   35.509998   36.024284   31.438864
# 4     2010-09-03   36.441429   36.968571   36.357143   36.967144   32.261719
# 5     2010-09-07   36.662857   37.075714   36.607143   36.830002   32.142021
# 6     2010-09-08   37.111427   37.770000   37.014286   37.560001   32.779102
# 7     2010-09-09   37.862858   38.074287   37.560001   37.581429   32.797817
# 8     2010-09-10   37.598572   37.785713   37.342857   37.630001   32.840195
# 9     2010-09-13   37.974285   38.325714   37.965714   38.148571   33.292770
# 10    2010-09-14   38.029999   38.452858   37.931427   38.294285   33.419926
# 2258  2019-08-20  210.880005  213.350006  210.320007  210.360001  210.360001
# 2259  2019-08-21  212.990005  213.649994  211.600006  212.639999  212.639999
# 2260  2019-08-22  213.190002  214.440002  210.750000  212.460007  212.460007
# 2261  2019-08-23  209.429993  212.050003  201.000000  202.639999  202.639999
# 2262  2019-08-26  205.860001  207.190002  205.059998  206.490005  206.490005
# 2263  2019-08-27  207.860001  208.550003  203.529999  204.160004  204.160004
#
#          Volume
# 0      95822300
# 1     105196700
# 2     174259400
# 3     103856900
# 4     130197200
# 5      85639400
# 6     131637800
# 7     109643800
# 8      96885600
# 9      97195000
# 10    102037600
# 11    107342200
# 12    163025800
# 13    158619300
# 14    164669400
# 15    167018600
# 16    146322400
# 17    196529200
# 18    162372000
# 19    120708700
# 20    258760600
# 21    117411000
# 22    168347900
# 23    112035700
# 24    108825500
# 25    125491800
# 26    167717200
# 27    102099900
# 28    164600800
# 29    106938300
# ...         ...
# 2234   14107500
# 2235   18582200
# 2236   20929300
# 2237   22277900
# 2238   18355200
# 2239   14991600
# 2240   13909600
# 2241   17618900
# 2242   21673400
# 2243   33935700
# 2244   69281400
# 2245   54017900
# 2246   40862100
# 2247   52393000
# 2248   35824800
# 2249   33364400
# 2250   27009500
# 2251   24619700
# 2252   22474900
# 2253   47218500
# 2254   36547400
# 2255   27227400
# 2256   27620400
# 2257   24413600
# 2258   26884300
# 2259   21535400
# 2260   22253700
# 2261   46818000
# 2262   26043600
# 2263   25873300
#
# [2264 rows x 7 columns]

# %%
aapl.shape
# Out:
# (2264, 7)

# %%
aapl.T
# Out:
#                  0           1           2           3           4     \
# Date       2010-08-30  2010-08-31  2010-09-01  2010-09-02  2010-09-03
# Open          34.3943       34.55     35.3529     35.8943     36.4414
# High          35.1071     34.9371     35.9229     36.0243     36.9686
# Low           34.3829     34.3357     35.1829       35.51     36.3571
# Close         34.6429     34.7286     35.7614     36.0243     36.9671
# Adj Close     30.2333     30.3081     31.2095     31.4389     32.2617
# Volume       95822300   105196700   174259400   103856900   130197200
#
#                  5           6           7           8           9     ...  \
# Date       2010-09-07  2010-09-08  2010-09-09  2010-09-10  2010-09-13  ...
# Open          36.6629     37.1114     37.8629     37.5986     37.9743  ...
# High          37.0757       37.77     38.0743     37.7857     38.3257  ...
# Low           36.6071     37.0143       37.56     37.3429     37.9657  ...
# Close           36.83       37.56     37.5814       37.63     38.1486  ...
# Adj Close      32.142     32.7791     32.7978     32.8402     33.2928  ...
# Volume       85639400   131637800   109643800    96885600    97195000  ...
#
#                  2254        2255        2256        2257        2258  \
# Date       2019-08-14  2019-08-15  2019-08-16  2019-08-19  2019-08-20
# Open           203.16      203.46      204.28      210.62      210.88
# High           206.44      205.14      207.16      212.73      213.35
# Low            202.59      199.67      203.84      210.03      210.32
# Close          202.75      201.74       206.5      210.35      210.36
# Adj Close      202.75      201.74       206.5      210.35      210.36
# Volume       36547400    27227400    27620400    24413600    26884300
#
#                  2259        2260        2261        2262        2263
# Date       2019-08-21  2019-08-22  2019-08-23  2019-08-26  2019-08-27
# Open           212.99      213.19      209.43      205.86      207.86
# High           213.65      214.44      212.05      207.19      208.55
# Low             211.6      210.75         201      205.06      203.53
# Close          212.64      212.46      202.64      206.49      204.16
# Adj Close      212.64      212.46      202.64      206.49      204.16
# Volume       21535400    22253700    46818000    26043600    25873300
#
# [7 rows x 2264 columns]

# %%
tsla.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
tsla.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
aapl.values
# Out:
# array([['2010-08-30', 34.394287, 35.107143, ..., 34.642857, 30.23328,
#         95822300],
#        ['2010-08-31', 34.549999, 34.937141, ..., 34.728573, 30.308084,
#         105196700],
#        ['2010-09-01', 35.352856, 35.922855, ..., 35.761429, 31.209463,
#         174259400],
#        ...,
#        ['2019-08-23', 209.429993, 212.05000299999998, ..., 202.639999,
#         202.639999, 46818000],
#        ['2019-08-26', 205.860001, 207.190002, ..., 206.490005,
#         206.490005, 26043600],
#        ['2019-08-27', 207.860001, 208.550003, ..., 204.16000400000001,
#         204.16000400000001, 25873300]], dtype=object)

# %%
tsla.size
# Out:
# 15848

# %%
tsla.empty
# Out:
# False

# %%
aapl.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2264.000000  2264.000000  2264.000000  2264.000000  2264.000000
# mean    110.663236   111.650504   109.654572   110.671857   104.338106
# std      48.393816    48.839651    47.999213    48.421697    49.995643
# min      34.394287    34.937141    34.335712    34.642857    30.233280
# 25%      72.306785    72.925354    71.717503    72.345354    64.476294
# 50%     101.114998   102.084999   100.350003   101.090001    94.225952
# 75%     145.627498   147.145000   144.850006   145.972496   140.961929
# max     230.779999   233.470001   229.779999   232.070007   228.523819
#
#              Volume
# count  2.264000e+03
# mean   7.013072e+07
# std    5.286818e+07
# min    1.136200e+07
# 25%    3.149515e+07
# 50%    5.284570e+07
# 75%    9.516045e+07
# max    4.702495e+08

# %%
tsla.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-08-30  34.394287  35.107143  34.382858  34.642857  30.233280
# 1  2010-08-31  34.549999  34.937141  34.335712  34.728573  30.308084
# 2  2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 3  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 4  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
#
#       Volume
# 0   95822300
# 1  105196700
# 2  174259400
# 3  103856900
# 4  130197200

# %%
tsla.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999800  0.999745  0.999540   0.998732 -0.613167
# High       0.999800  1.000000  0.999684  0.999770   0.998995 -0.610108
# Low        0.999745  0.999684  1.000000  0.999794   0.999007 -0.618474
# Close      0.999540  0.999770  0.999794  1.000000   0.999207 -0.614847
# Adj Close  0.998732  0.998995  0.999007  0.999207   1.000000 -0.618872
# Volume    -0.613167 -0.610108 -0.618474 -0.614847  -0.618872  1.000000

# %%
aapl_close = aapl.loc[:,'Close']

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(aapl_close.index, aapl_close, label='aapl')
ax.plot(aapl_close.index, aapl_close.rolling(window=50).mean(), label='50-day moving average')
ax.plot(aapl_close.index, aapl_close.rolling(window+200).mean(), label='200-day moving average')

#I'm going to set the x label to Date
ax.set_xlabel('Date')
ax.set_ylabel('Closing price ($)')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-3f962a7f1261> in <module>
#       3 ax.plot(aapl_close.index, aapl_close, label='aapl')
#       4 ax.plot(aapl_close.index, aapl_close.rolling(window=50).mean(), label='50-day moving average')
# ----> 5 ax.plot(aapl_close.index, aapl_close.rolling(window+200).mean(), label='200-day moving average')
#       6
#       7 #I'm going to set the x label to Date
#
# NameError: name 'window' is not defined
